# %%
import sys
sys.path.insert(0, '../')
import keras
import pandas as pd
import numpy as np
import matchzoo as mz
# Out:
# Using TensorFlow backend.

# %%
train_pack = mz.datasets.wiki_qa.load_data('train', task='ranking')
valid_pack = mz.datasets.wiki_qa.load_data('dev', task='ranking', filter=True)
predict_pack = mz.datasets.wiki_qa.load_data('test', task='ranking', filter=True)

# %%
preprocessor = mz.preprocessors.BasicPreprocessor(fixed_length_left=10, fixed_length_right=40, remove_stop_words=True)
train_pack_processed = preprocessor.fit_transform(train_pack)
# Out:
# Processing text_left with chain_transform of TokenizeUnit => LowercaseUnit => PuncRemovalUnit: 100%|██████████| 2118/2118 [00:00<00:00, 9507.73it/s]
# Processing text_right with chain_transform of TokenizeUnit => LowercaseUnit => PuncRemovalUnit: 100%|██████████| 18841/18841 [00:03<00:00, 5215.26it/s]
# Processing text_right with append: 100%|██████████| 18841/18841 [00:00<00:00, 884422.08it/s]
# Building FrequencyFilterUnit from a datapack.: 100%|██████████| 18841/18841 [00:00<00:00, 143382.59it/s]
# Processing text_right with transform: 100%|██████████| 18841/18841 [00:00<00:00, 91815.30it/s]
# Processing text_left with extend: 100%|██████████| 2118/2118 [00:00<00:00, 676583.08it/s]
# Processing text_right with extend: 100%|██████████| 18841/18841 [00:00<00:00, 757044.83it/s]
# Building VocabularyUnit from a datapack.: 100%|██████████| 404432/404432 [00:00<00:00, 3016822.02it/s]
# Processing text_left with chain_transform of TokenizeUnit => LowercaseUnit => PuncRemovalUnit: 100%|██████████| 2118/2118 [00:00<00:00, 9653.97it/s]
# Processing text_right with chain_transform of TokenizeUnit => LowercaseUnit => PuncRemovalUnit: 100%|██████████| 18841/18841 [00:03<00:00, 5259.72it/s]
# Processing text_right with transform: 100%|██████████| 18841/18841 [00:00<00:00, 148527.66it/s]
# Processing text_left with transform: 100%|██████████| 2118/2118 [00:00<00:00, 243531.33it/s]
# Processing text_right with transform: 100%|██████████| 18841/18841 [00:00<00:00, 132136.70it/s]
# Processing text_left with transform: 100%|██████████| 2118/2118 [00:00<00:00, 130761.38it/s]
# Processing text_right with transform: 100%|██████████| 18841/18841 [00:00<00:00, 102513.49it/s]
# Processing length_left with len: 100%|██████████| 2118/2118 [00:00<00:00, 717803.48it/s]
# Processing length_right with len: 100%|██████████| 18841/18841 [00:00<00:00, 819530.65it/s]

# %%
valid_pack_processed = preprocessor.transform(valid_pack)
predict_pack_processed = preprocessor.transform(predict_pack)
# Out:
# Processing text_left with chain_transform of TokenizeUnit => LowercaseUnit => PuncRemovalUnit: 100%|██████████| 122/122 [00:00<00:00, 9187.96it/s]
# Processing text_right with chain_transform of TokenizeUnit => LowercaseUnit => PuncRemovalUnit: 100%|██████████| 1115/1115 [00:00<00:00, 5350.75it/s]
# Processing text_right with transform: 100%|██████████| 1115/1115 [00:00<00:00, 150157.30it/s]
# Processing text_left with transform: 100%|██████████| 122/122 [00:00<00:00, 146326.88it/s]
# Processing text_right with transform: 100%|██████████| 1115/1115 [00:00<00:00, 142585.11it/s]
# Processing text_left with transform: 100%|██████████| 122/122 [00:00<00:00, 98046.58it/s]
# Processing text_right with transform: 100%|██████████| 1115/1115 [00:00<00:00, 102612.10it/s]
# Processing length_left with len: 100%|██████████| 122/122 [00:00<00:00, 174822.37it/s]
# Processing length_right with len: 100%|██████████| 1115/1115 [00:00<00:00, 627148.85it/s]
# Processing text_left with chain_transform of TokenizeUnit => LowercaseUnit => PuncRemovalUnit: 100%|██████████| 237/237 [00:00<00:00, 9895.97it/s]
# Processing text_right with chain_transform of TokenizeUnit => LowercaseUnit => PuncRemovalUnit: 100%|██████████| 2300/2300 [00:00<00:00, 4525.73it/s]
# Processing text_right with transform: 100%|██████████| 2300/2300 [00:00<00:00, 147406.93it/s]
# Processing text_left with transform: 100%|██████████| 237/237 [00:00<00:00, 169027.38it/s]
# Processing text_right with transform: 100%|██████████| 2300/2300 [00:00<00:00, 153137.54it/s]
# Processing text_left with transform: 100%|██████████| 237/237 [00:00<00:00, 101361.28it/s]
# Processing text_right with transform: 100%|██████████| 2300/2300 [00:00<00:00, 103464.21it/s]
# Processing length_left with len: 100%|██████████| 237/237 [00:00<00:00, 307184.81it/s]
# Processing length_right with len: 100%|██████████| 2300/2300 [00:00<00:00, 716495.78it/s]

# %%
ranking_task = mz.tasks.Ranking(loss=mz.losses.RankHingeLoss())
ranking_task.metrics = [
    mz.metrics.NormalizedDiscountedCumulativeGain(k=3),
    mz.metrics.NormalizedDiscountedCumulativeGain(k=5),
    mz.metrics.MeanAveragePrecision()
]

# %%
model = mz.models.MatchPyramid()
model.params['input_shapes'] = preprocessor.context['input_shapes']
model.params['task'] = ranking_task
model.params['embedding_input_dim'] = preprocessor.context['vocab_size'] + 1
model.params['embedding_output_dim'] = 50
model.params['embedding_trainable'] = False
model.params['optimizer'] = 'adam'
model.guess_and_fill_missing_params()
model.build()
model.compile()
model.backend.summary()
# Out:
# Parameter "name" set to MatchPyramid.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_left (InputLayer)          (None, 10)           0
# __________________________________________________________________________________________________
# text_right (InputLayer)         (None, 40)           0
# __________________________________________________________________________________________________
# embedding (Embedding)           multiple             833700      text_left[0][0]
#                                                                  text_right[0][0]
# __________________________________________________________________________________________________
# matching_layer_1 (MatchingLayer (None, 10, 40, 1)    0           embedding[0][0]
#                                                                  embedding[1][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 10, 40, 32)   320         matching_layer_1[0][0]
# __________________________________________________________________________________________________
# dpool_index (InputLayer)        (None, 10, 40, 3)    0
# __________________________________________________________________________________________________
# dynamic_pooling_layer_1 (Dynami (None, 3, 10, 32)    0           conv2d_1[0][0]
#                                                                  dpool_index[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 960)          0           dynamic_pooling_layer_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 960)          0           flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            961         dropout_1[0][0]
# ==================================================================================================
# Total params: 834,981
# Trainable params: 1,281
# Non-trainable params: 833,700
# __________________________________________________________________________________________________

# %%
glove_embedding = mz.datasets.embeddings.load_glove_embedding(dimension=50)
embedding_matrix = glove_embedding.build_matrix(preprocessor.context['vocab_unit'].state['term_index'])

# %%
model.load_embedding_matrix(embedding_matrix)

# %%
pred_x, pred_y = predict_pack_processed[:].unpack()
evaluate = mz.callbacks.EvaluateAllMetrics(model, x=pred_x, y=pred_y, batch_size=len(pred_x))
len(pred_y)
# Out:
# 2341

# %%
train_generator = mz.DPoolPairDataGenerator(train_pack_processed,
                                            fixed_length_left=10,
                                            fixed_length_right=40,
                                            num_dup=2,
                                            num_neg=1,
                                            batch_size=20)
len(train_generator)
# Out:
# 102

# %%
history = model.fit_generator(train_generator, epochs=3, callbacks=[], workers=3, use_multiprocessing=True)
# Out:
# Epoch 1/3
# 102/102 [==============================] - 1s 10ms/step - loss: 0.6361
# Epoch 2/3
# Epoch 1/3
# 102/102 [==============================] - 1s 10ms/step - loss: 0.5565
# Epoch 3/3
# 102/102 [==============================] - 1s 11ms/step - loss: 0.5100
